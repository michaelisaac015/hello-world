# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelisaac015/hello-world/blob/master/ts0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

#Use to import the file into google Colab drive
from google.colab import files 
#Use to import io, which opens the file from the Colab drive
import io

uploaded = files.upload()

# Now use the below code to read the csv in pandas' dataframe
df = pd.read_csv(io.StringIO(uploaded['daily-total-female-births.csv'].decode('utf-8')))

ts = pd.DataFrame(columns=['Week','X1','X2','X3','X4','X5','X6','Y'])
tsw = []
ts1 = []
ts2 = []
ts3 = []
ts4 = []
ts5 = []
ts6 = []
tsy = []

for i in range(0,len(df)-7,7):       
    ts1.append(df['Births'][i])
    ts2.append(df['Births'][i+1])
    ts3.append(df['Births'][i+2])
    ts4.append(df['Births'][i+3])
    ts5.append(df['Births'][i+4])
    ts6.append(df['Births'][i+5])
    tsy.append(df['Births'][i+6])    
ts['X1'] = ts1
ts['X2'] = ts2
ts['X3'] = ts3
ts['X4'] = ts4
ts['X5'] = ts5
ts['X6'] = ts6
ts['Y'] = tsy

ts['Week'] = ts.index+1
ts
# Out:
#      <input type="file" id="files-2b7ef8b8-d78e-46fb-99af-35b17a4af4c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b7ef8b8-d78e-46fb-99af-35b17a4af4c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving daily-total-female-births.csv to daily-total-female-births (2).csv
#     Week  X1  X2  X3  X4  X5  X6   Y
# 0      1  35  32  30  31  44  29  45
# 1      2  43  38  27  38  33  55  47
# 2      3  45  37  50  43  41  52  34
# 3      4  53  39  32  37  43  39  35
# 4      5  44  38  24  23  31  44  38
# 5      6  50  38  51  31  31  51  36
# 6      7  45  51  34  52  47  45  46
# 7      8  39  48  37  35  52  42  45
# 8      9  39  37  30  35  28  45  34
# 9     10  36  50  44  39  32  39  45
# 10    11  43  39  31  27  30  42  46
# ...
